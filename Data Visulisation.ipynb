# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Visualizing statistical relationships

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Data-Visualization/main/Automobile.csv")

# %%
df.head(5)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %% [markdown]
# Scatterplot using Seaborn

# %%
sns.relplot(x="fuel_system", y="peak_rpm", data = df)

# %% [markdown]
# SNS.relplot using Seaborn

# %%
sns.relplot(x="fuel_system", y="peak_rpm",hue = "symboling", data = df)

# %% [markdown]
# Hue Plot

# %%
sns.relplot(x="fuel_system", y="peak_rpm",hue = "price", data = df)

# %% [markdown]
# We can also change the size of each point

# %%
sns.relplot(x="fuel_system", y="peak_rpm",size="symboling", data = df)

# %% [markdown]
# Plotting Categorical Data

# %%
df2 = pd.read_csv(r"https://raw.githubusercontent.com/Premalatha-success/Data-Visualization/main/Automobile.csv")
df2.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.catplot(x="body_style", y="wheel_base", data=df2)

# %% [markdown]
# Jitter

# %%
sns.catplot(x="body_style", y="wheel_base",jitter = False, data=df2)

# %% [markdown]
# Hue

# %%
sns.catplot(x="body_style", y="wheel_base",hue = "drive_wheels", data=df2)

# %%
sns.catplot(x="body_style", y="wheel_base",kind = "swarm", data=df2)
# Out:
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="body_style", y="wheel_base",hue = "drive_wheels",kind = "swarm", data=df2)
# Out:
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# BoxPlot

# %%
sns.catplot(x="body_style", y="wheel_base",hue = "drive_wheels",kind = "box", data=df2)

# %% [markdown]
# ViolinPlot

# %%
sns.catplot(x="body_style", y="wheel_base",hue = "drive_wheels",kind = "violin", data=df2)

# %% [markdown]
# Barplot

# %%
sns.catplot(x="body_style", y="wheel_base",hue = "drive_wheels",kind = "bar", data=df2)

# %% [markdown]
# Point Plot Using Seaborn

# %%
sns.catplot(x="body_style", y="wheel_base",hue = "drive_wheels",kind = "point", data=df2)

# %% [markdown]
# Visualizing the Distribution of a Dataset

# %% [markdown]
# Plotting Univariate Distributions

# %%
sns.distplot(df2.stroke)
# Out:
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stroke', ylabel='Density'>

# %% [markdown]
# Histogram using Seaborn

# %%
sns.distplot(df2.stroke, kde=False, rug = True)
# Out:
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\darshan\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stroke'>

# %% [markdown]
# Plotting Bivariate Distributions
# Hexplot
# KDE plot
# Boxen plot
# Ridge plot (Joyplot)

# %%
sns.jointplot(x="body_style", y="stroke", data=df2);

# %% [markdown]
# Hexplot using Seaborn

# %%
sns.jointplot(x=df2.body_style, y=df2.stroke, kind="hex", data = df2)

# %% [markdown]
# KDE Plot using Seaborn

# %%
sns.jointplot(x="normalized_losses", y="stroke", data=df2,kind="kde");

# %% [markdown]
# Heatmaps using Seaborn

# %%
corrmat = df2.corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Boxen Plot using Seaborn

# %%
sns.catplot(x="body_style", y="stroke", data=df2, kind="boxen",height=4, aspect=2.7, hue = "drive_wheels")

# %% [markdown]
# Ridge Plot using seaborn

# %%
# Initialize the FacetGrid object
g = sns.FacetGrid(df2, row="symboling", hue="drive_wheels", aspect=5, height=3)

# # Draw the densities in a few steps
g.map(sns.kdeplot, "symboling", shade=True, alpha=1, lw=3.5, bw=.2)
g.map(sns.kdeplot, "symboling", color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2)

# # Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "symboling")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# # Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)

# %% [markdown]
# Visualizing Pairwise Relationships in a Dataset

# %%
sns.pairplot(df2)
